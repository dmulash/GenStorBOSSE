# %%
import sys
import os

# Adds the parent directory to the python path
sys.path.append(os.path.abspath(os.path.join('..')))

from GenStorBOSSE.pvscm_nrel_bess_model import GenStorBOSSEModel

model = GenStorBOSSEModel()
li_ion_cost = model.calculate_li_ion_cost_per_kwh()
print(f"Li-Ion Battery Cabinet Cost: ${li_ion_cost:.2f}/kWh_cap")
# Out:
# Li-Ion Battery Cabinet Cost: $204.11/kWh_cap

# %%
breakdown = model.get_li_ion_cost_breakdown()

print("--- Li-Ion Cost Breakdown ($/kWh_cap) ---")
for component, cost in breakdown.items():
    print(f"{component:30}: ${cost:8.2f}")
# Out:
# --- Li-Ion Cost Breakdown ($/kWh_cap) ---
# li_ion_cells                  : $   96.30
# battery_packs                 : $   25.00
# enclosure                     : $   20.00
# labor                         : $    9.98
# electricity                   : $    2.44
# depreciation                  : $    0.77
# maintenance                   : $    0.28
# profit                        : $   44.94
# shipping                      : $    9.40
# passthrough_credit            : $   -5.00
# total_li_ion_cost_per_kwh     : $  204.11

# %%
breakdown = model.get_bi_directional_inverter_cost_breakdown()

print("--- Bi-Directional Inverter Cost Breakdown ($/kWh_cap) ---")
for component, cost in breakdown.items():
    print(f"{component:40}: ${cost:8.2f}")
# Out:
# --- Bi-Directional Inverter Cost Breakdown ($/kWh_cap) ---
# bi_directional_inverter                 : $   25.00
# total_bi_directional_inverter_per_kwh   : $   25.00

# %%
breakdown = model.get_sbos_cost_breakdown()

print("--- SBOS Cost Breakdown ($/kWh_cap) ---")
for component, cost in breakdown.items():
    print(f"{component:30}: ${cost:8.2f}")
# Out:
# --- SBOS Cost Breakdown ($/kWh_cap) ---
# site_prep                     : $    1.33
# concrete_pads                 : $    3.20
# total_sbos_per_kwh            : $    4.53

# %%
breakdown = model.get_ebos_cost_breakdown()

print("--- EBOS Cost Breakdown ($/kWh_cap) ---")
for component, cost in breakdown.items():
    print(f"{component:40}: ${cost:8.2f}")
# Out:
# --- EBOS Cost Breakdown ($/kWh_cap) ---
# transformer                             : $   10.00
# switch_gear                             : $    2.03
# conductors                              : $    5.25
# breaker_dc                              : $    4.69
# grounding                               : $    2.38
# scada                                   : $    0.88
# substation                              : $   10.31
# transmission                            : $    7.08
# network_upgrade                         : $    0.00
# shipping                                : $    0.60
# total_ebos_per_kwh                      : $   43.21

# %%
breakdown = model.get_installation_cost_breakdown()

print("--- Installation Labor Cost Breakdown ($/kWh_cap) ---")
for component, cost in breakdown.items():
    print(f"{component:40}: ${cost:8.2f}")
# Out:
# --- Installation Labor Cost Breakdown ($/kWh_cap) ---
# installation                            : $    2.43
# total_installation_per_kwh              : $    2.43

# %%
breakdown = model.get_permitting_cost_breakdown()

print("--- Permitting Cost Breakdown ($/kWh_cap) ---")
for component, cost in breakdown.items():
    print(f"{component:40}: ${cost:8.2f}")
    
breakdown = model.get_interconnection_cost_breakdown()

print("--- Interconnection Cost Breakdown ($/kWh_cap) ---")
for component, cost in breakdown.items():
    print(f"{component:40}: ${cost:8.2f}")
# Out:
# --- Permitting Cost Breakdown ($/kWh_cap) ---
# permitting                              : $    0.33
# total_permitting_per_kwh                : $    0.33
# --- Interconnection Cost Breakdown ($/kWh_cap) ---
# interconnection                         : $    8.89
# total_interconnection_per_kwh           : $    8.89

# %%
breakdown = model.get_sales_tax_cost_breakdown()

print("--- Sales Tax Cost Breakdown ($/kWh_cap) ---")
for component, cost in breakdown.items():
    print(f"{component:40}: ${cost:8.2f}")
# Out:
# --- Sales Tax Cost Breakdown ($/kWh_cap) ---
# sales_tax                               : $   16.06
# total_sales_tax_per_kwh                 : $   16.06

# %%
breakdown = model.get_contingency_cost_breakdown()

print("--- Contingency Cost Breakdown ($/kWh_cap) ---")
for component, cost in breakdown.items():
    print(f"{component:40}: ${cost:8.2f}")
# Out:
# --- Contingency Cost Breakdown ($/kWh_cap) ---
# contingency                             : $    6.92
# total_contingency_per_kwh               : $    6.92

# %%
breakdown = model.get_epc_overhead_cost_breakdown()

print("--- EPC Overhead Cost Breakdown ($/kWh_cap) ---")
for component, cost in breakdown.items():
    print(f"{component:40}: ${cost:8.2f}")
# Out:
# --- EPC Overhead Cost Breakdown ($/kWh_cap) ---
# warehousing                             : $    0.03
# logistics                               : $    0.94
# engineering                             : $    0.16
# outreach                                : $    0.36
# management                              : $    4.44
# total_epc_overhead_per_kwh              : $    5.93

# %%
breakdown = model.get_profit_cost_breakdown()

print("--- Profit Cost Breakdown ($/kWh_cap) ---")
for component, cost in breakdown.items():
    print(f"{component:40}: ${cost:8.2f}")
# Out:
# --- Profit Cost Breakdown ($/kWh_cap) ---
# profit                                  : $   13.84
# total_profit_per_kwh                    : $   13.84

# %%
model.get_cost_breakdown()
# Out:
# {'li_ion': 204.1125,
#  'inverter': 25.0,
#  'sbos': 4.533333333333333,
#  'ebos': 43.21458333333334,
#  'installation': 2.428066666666667,
#  'permitting': 0.3333333333333333,
#  'interconnection': 8.891666666666667,
#  'sales_tax': 16.057904166666667,
#  'contingency': 6.921510416666667,
#  'epc_overhead': 5.9279375,
#  'developer_profit': 13.843020833333334,
#  'total_project_cost_per_kwh': 331.26385624999995}

# %%
model.get_cost_breakdown(higher_resolution=True)
# Out:
# {'li_ion': {'total': 204.1125,
#   'components': {'li_ion_cells': 96.3,
#    'battery_packs': 25.0,
#    'enclosure': 20.0,
#    'labor': 9.98,
#    'electricity': 2.44,
#    'depreciation': 0.77,
#    'maintenance': 0.28,
#    'profit': 44.9425,
#    'shipping': 9.4,
#    'passthrough_credit': -5.0}},
#  'inverter': {'total': 25.0, 'components': {'bi_directional_inverter': 25.0}},
#  'sbos': {'total': 4.533333333333333,
#   'components': {'site_prep': 1.3333333333333335, 'concrete_pads': 3.2}},
#  'ebos': {'total': 43.21458333333334,
#   'components': {'transformer': 10.0,
#    'switch_gear': 2.03125,
#    'conductors': 5.25,
#    'breaker_dc': 4.6875,
#    'grounding': 2.375,
#    'scada': 0.875,
#    'substation': 10.3125,
#    'transmission': 7.083333333333334,
#    'network_upgrade': 0.0,
#    'shipping': 0.6}},
#  'installation': {'total': 2.428066666666667,
#   'components': {'installation': 2.428066666666667}},
#  'permitting': {'total': 0.3333333333333333,
#   'components': {'permitting': 0.3333333333333333}},
#  'interconnection': {'total': 8.891666666666667,
#   'components': {'interconnection': 8.891666666666667}},
#  'sales_tax': {'total': 16.057904166666667,
#   'components': {'sales_tax': 16.057904166666667}},
#  'contingency': {'total': 6.921510416666667,
#   'components': {'contingency': 6.921510416666667}},
#  'epc_overhead': {'total': 5.9279375,
#   'components': {'warehousing': 0.029333333333333336,
#    'logistics': 0.9400000000000001,
#    'engineering': 0.16333333333333333,
#    'outreach': 0.36,
#    'management': 4.435270833333333}},
#  'developer_profit': {'total': 13.843020833333334,
#   'components': {'profit': 13.843020833333334}},
#  'total_project_cost_per_kwh': 331.26385624999995}

# %% [markdown]
# # Run with a Configuration File

# %%
# Initialize using the file
model = GenStorBOSSEModel.from_config_file("../../configs/60MW_2h_battery_no_interconnection.yaml")

# Check a value that wasn't in the file (it will be the default)
print(f"Battery Capacity: {model.config['BatteryCapacity']}") # 60

# Check a value that WAS in the file
print(f"Battery Duration: {model.config['BatteryDuration']}") # 2

# Run the breakdown
model.get_cost_breakdown(higher_resolution=True)
# Out:
# Battery Capacity: 60
# Battery Duration: 2
# {'li_ion': {'total': 210.3625,
#   'components': {'li_ion_cells': 96.3,
#    'battery_packs': 25.0,
#    'enclosure': 20.0,
#    'labor': 9.98,
#    'electricity': 2.44,
#    'depreciation': 0.77,
#    'maintenance': 0.28,
#    'profit': 51.1925,
#    'shipping': 9.4,
#    'passthrough_credit': -5.0}},
#  'inverter': {'total': 50.0, 'components': {'bi_directional_inverter': 50.0}},
#  'sbos': {'total': 4.533333333333333,
#   'components': {'site_prep': 1.3333333333333335, 'concrete_pads': 3.2}},
#  'ebos': {'total': 86.42916666666667,
#   'components': {'transformer': 20.0,
#    'switch_gear': 4.0625,
#    'conductors': 10.5,
#    'breaker_dc': 9.375,
#    'grounding': 4.75,
#    'scada': 1.75,
#    'substation': 20.625,
#    'transmission': 14.166666666666668,
#    'network_upgrade': 0.0,
#    'shipping': 1.2}},
#  'installation': {'total': 2.428066666666667,
#   'components': {'installation': 2.428066666666667}},
#  'permitting': {'total': 0.3333333333333333,
#   'components': {'permitting': 0.3333333333333333}},
#  'interconnection': {'total': 0.0, 'components': {'interconnection': 0.0}},
#  'sales_tax': {'total': 20.376850000000005,
#   'components': {'sales_tax': 20.376850000000005}},
#  'contingency': {'total': 8.783125000000002,
#   'components': {'contingency': 8.783125000000002}},
#  'epc_overhead': {'total': 6.672583333333334,
#   'components': {'warehousing': 0.029333333333333336,
#    'logistics': 0.9400000000000001,
#    'engineering': 0.16333333333333333,
#    'outreach': 0.36,
#    'management': 5.179916666666667}},
#  'developer_profit': {'total': 17.566250000000004,
#   'components': {'profit': 17.566250000000004}},
#  'total_project_cost_per_kwh': 407.48520833333333}

# %%
model.get_cost_breakdown()
# Out:
# {'li_ion': 210.3625,
#  'inverter': 50.0,
#  'sbos': 4.533333333333333,
#  'ebos': 86.42916666666667,
#  'installation': 2.428066666666667,
#  'permitting': 0.3333333333333333,
#  'interconnection': 0.0,
#  'sales_tax': 20.376850000000005,
#  'contingency': 8.783125000000002,
#  'epc_overhead': 6.672583333333334,
#  'developer_profit': 17.566250000000004,
#  'total_project_cost_per_kwh': 407.48520833333333}

# %%
# Initialize using the file
model = GenStorBOSSEModel.from_config_file("../../configs/100MW_4h_battery.yaml")

# Check a value that wasn't in the file (it will be the default)
print(f"Battery Capacity: {model.config['BatteryCapacity']}") # 60

# Check a value that WAS in the file
print(f"Battery Duration: {model.config['BatteryDuration']}") # 2

# Run the breakdown
model.get_cost_breakdown(higher_resolution=True)
# Out:
# Battery Capacity: 100
# Battery Duration: 4
# {'li_ion': {'total': 204.1125,
#   'components': {'li_ion_cells': 96.3,
#    'battery_packs': 25.0,
#    'enclosure': 20.0,
#    'labor': 9.98,
#    'electricity': 2.44,
#    'depreciation': 0.77,
#    'maintenance': 0.28,
#    'profit': 44.9425,
#    'shipping': 9.4,
#    'passthrough_credit': -5.0}},
#  'inverter': {'total': 25.0, 'components': {'bi_directional_inverter': 25.0}},
#  'sbos': {'total': 4.533333333333333,
#   'components': {'site_prep': 1.3333333333333335, 'concrete_pads': 3.2}},
#  'ebos': {'total': 42.081250000000004,
#   'components': {'transformer': 10.0,
#    'switch_gear': 2.03125,
#    'conductors': 5.25,
#    'breaker_dc': 4.6875,
#    'grounding': 2.375,
#    'scada': 0.875,
#    'substation': 10.3125,
#    'transmission': 5.95,
#    'network_upgrade': 0.0,
#    'shipping': 0.6}},
#  'installation': {'total': 2.428066666666667,
#   'components': {'installation': 2.428066666666667}},
#  'permitting': {'total': 0.3333333333333333,
#   'components': {'permitting': 0.3333333333333333}},
#  'interconnection': {'total': 8.891666666666667,
#   'components': {'interconnection': 8.891666666666667}},
#  'sales_tax': {'total': 15.992170833333335,
#   'components': {'sales_tax': 15.992170833333335}},
#  'contingency': {'total': 6.893177083333334,
#   'components': {'contingency': 6.893177083333334}},
#  'epc_overhead': {'total': 5.916604166666667,
#   'components': {'warehousing': 0.029333333333333336,
#    'logistics': 0.9400000000000001,
#    'engineering': 0.16333333333333333,
#    'outreach': 0.36,
#    'management': 4.4239375}},
#  'developer_profit': {'total': 13.786354166666667,
#   'components': {'profit': 13.786354166666667}},
#  'total_project_cost_per_kwh': 329.96845625}

# %%
model.get_cost_breakdown()
# Out:
# {'li_ion': 204.1125,
#  'inverter': 25.0,
#  'sbos': 4.533333333333333,
#  'ebos': 42.081250000000004,
#  'installation': 2.428066666666667,
#  'permitting': 0.3333333333333333,
#  'interconnection': 8.891666666666667,
#  'sales_tax': 15.992170833333335,
#  'contingency': 6.893177083333334,
#  'epc_overhead': 5.916604166666667,
#  'developer_profit': 13.786354166666667,
#  'total_project_cost_per_kwh': 329.96845625}
